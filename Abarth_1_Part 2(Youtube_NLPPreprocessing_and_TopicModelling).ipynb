# %%
import pandas as pd
import pyLDAvis.gensim_models as gensimvis
import pyLDAvis
import matplotlib.pyplot as plt
from gensim.models import Word2Vec, Phrases
from gensim.models.phrases import Phraser
from gensim.utils import simple_preprocess
from gensim import corpora, models
import spacy
import string
import gensim
from gensim.models.coherencemodel import CoherenceModel
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %% [markdown]
# Trying to separate the video searches to their appropriate companies

# %%
df1 = pd.read_csv('df1_combined.csv')
df2 = pd.read_csv('df2_combined.csv')
# Out:
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/514336858.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('df2_combined.csv')

# %% [markdown]
# Associating the comments and videos to their appropriate companies

# %%
company_keywords = {
    'Abarth': ['Abarth', 'abarth', 'ABARTH'],
    'Fiat': ['Fiat', 'fiat', 'FIAT'],
    'Mini': ['Mini', 'mini', 'MINI'],
    'Peugeot': ['Peugeot', 'peugeot', 'PEUGEOT'],
    'Volkswagen': ['Volkswagen', 'volkswagen', 'VW', 'vw', 'Vw'],
    'Tesla': ['Tesla', 'tesla', 'TESLA']
}

#This function assigns the comments to the companies
def assign_company(row):
    for company, keywords in company_keywords.items():
        if any(keyword in str(row['Post_Title']) or keyword in str(row['Post_Content']) for keyword in keywords):
            return company
    return 'Unknown'

df1['Company'] = df1.apply(assign_company, axis=1)

# %%
df1[df1['Company'] == 'Unknown'].head()
# Out:
#         Post_id                                         Post_Title
# 53  GI9pkcFJXV4  All about the Taurozzi Pendulum Engine 🧠 and w...  \
# 54  9lse1SfDq7M  Engine lubrication system / How does it work? ...
# 60  W94iksaQwUo                          How Ignition System Works
# 61  90uUdwJBEu4  Learn about every Engine Layout in just one vi...
# 64  x70VqMrXrbs  Car Engine Parts & Their Functions Explained i...
#
#                 Author                  Date
# 53         Repairman22  2023-01-21T14:00:08Z  \
# 54      CARinfo3d (En)  2022-12-07T13:47:38Z
# 60   Automotive System  2012-08-13T12:55:59Z
# 61  The Engineers Post  2023-01-02T13:16:16Z
# 64  The Engineers Post  2021-04-17T11:39:00Z
#
#                                          Post_Content  Comment_Number
# 53  In this video we analyze the Taurozzi pendulum...            2371  \
# 54  The internal combustion engine contains numero...              66
# 60  Know the basic working of an automobile igniti...             949
# 61  Straight/Inline engine:\nThe straight or inlin...             204
# 64  List of Car Engine Parts | TheEngineersPost\n\...             793
#
#     Net_Like    Views  Company
# 53     31430  1540034  Unknown
# 54      4153   165024  Unknown
# 60     32122  4814980  Unknown
# 61      7424   380541  Unknown
# 64    109477  4054744  Unknown

# %% [markdown]
# Associating the df2 comments to the videos from df1 using the Post_id

# %%
#Mapping to df2 to remove unwanted video comments
merged_df2 = df2.merge(df1[['Post_id', 'Company']], on='Post_id', how='left')

# %%
merged_df2.head()
# Out:
#                     Unique_id      Post_id            Author
# 0  UgwxZe_9rq6Divz2B6V4AaABAg  eQlcDSnItRk     Tomas Juricek  \
# 1  UgyaJ0l-wY032jA6YsR4AaABAg  eQlcDSnItRk       Todd Turner
# 2  Ugxp60x3am7lNpJjYt94AaABAg  eQlcDSnItRk  PoltergeistWorks
# 3  UgxfZcCbo05HhzRi1Ht4AaABAg  eQlcDSnItRk         Spooligan
# 4  UgxZboo7_6pqKXGUAt94AaABAg  eQlcDSnItRk     Miguel Afonso
#
#                    Date                                    Comment_Content
# 0  2023-05-27T08:14:43Z                                       Not more car  \
# 1  2023-05-21T12:25:06Z  If Hydrocarbons came from dinosaurs how many o...
# 2  2023-05-20T19:08:31Z  Less power, less range, fake noise and twice t...
# 3  2023-05-17T10:54:08Z  TF?!? 96mph? A prius does 0 to 60 faster than ...
# 4  2023-05-16T22:44:14Z  Even slower that a 595 I reckon, and you can h...
#
#    Reply_id  Reply_Count Parent_id Company
# 0       0.0          NaN       NaN  Abarth
# 1       0.0          NaN       NaN  Abarth
# 2       0.0          NaN       NaN  Abarth
# 3       0.0          NaN       NaN  Abarth
# 4       0.0          NaN       NaN  Abarth

# %%
#Checking the length of the Unknown in df1 and df2
print(len(df1[df1['Company'] == 'Unknown']))
print(len(merged_df2[merged_df2['Company']=='Unknown']))
# Out:
# 33
# 26380

# %%
#Dropping the NaN values
merged_df2 = merged_df2.dropna(subset=['Comment_Content'])

#Dropping Unknown in Company
merged_df1 = df1[df1['Company'] != 'Unknown']
merged_df2 = merged_df2[merged_df2['Company'] != 'Unknown']

# %% [markdown]
# **Dealing with different languages in comments of df2**

# %%
#Library is used for detecting the language
from langdetect import detect

#Function used for running the comments through to detect the language
def detect_language(text):
    try:
        return detect(text)
    except:
        return 'unknown'

#Creates a new column 'language' in merged_df2 to detect the language in the comment
merged_df2['language'] = merged_df2['Comment_Content'].apply(detect_language)

# %%
merged_df2.head()
# Out:
#                     Unique_id      Post_id            Author
# 0  UgwxZe_9rq6Divz2B6V4AaABAg  eQlcDSnItRk     Tomas Juricek  \
# 1  UgyaJ0l-wY032jA6YsR4AaABAg  eQlcDSnItRk       Todd Turner
# 2  Ugxp60x3am7lNpJjYt94AaABAg  eQlcDSnItRk  PoltergeistWorks
# 3  UgxfZcCbo05HhzRi1Ht4AaABAg  eQlcDSnItRk         Spooligan
# 4  UgxZboo7_6pqKXGUAt94AaABAg  eQlcDSnItRk     Miguel Afonso
#
#                    Date                                    Comment_Content
# 0  2023-05-27T08:14:43Z                                       Not more car  \
# 1  2023-05-21T12:25:06Z  If Hydrocarbons came from dinosaurs how many o...
# 2  2023-05-20T19:08:31Z  Less power, less range, fake noise and twice t...
# 3  2023-05-17T10:54:08Z  TF?!? 96mph? A prius does 0 to 60 faster than ...
# 4  2023-05-16T22:44:14Z  Even slower that a 595 I reckon, and you can h...
#
#    Reply_id  Reply_Count Parent_id Company language
# 0       0.0          NaN       NaN  Abarth       ro
# 1       0.0          NaN       NaN  Abarth       en
# 2       0.0          NaN       NaN  Abarth       en
# 3       0.0          NaN       NaN  Abarth       en
# 4       0.0          NaN       NaN  Abarth       en

# %%
#Saving the file
#merged_df1.to_csv('merged_df1.csv', index=False)
#merged_df2.to_csv('merged_df2.csv', index=False)

# %% [markdown]
# LOADING THE LATEST FILES (Checkpoint purposes)

# %%
#Loading the file
merged_df1 = pd.read_csv('merged_df1.csv')
merged_df2 = pd.read_csv('merged_df2.csv')
# Out:
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/706945961.py:3: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   merged_df2 = pd.read_csv('merged_df2.csv')

# %%
print(len(merged_df1))
print(len(merged_df2))
# Out:
# 470
# 123156

# %%
print(len(merged_df1[merged_df1['Company']=='Unknown']))
print(len(merged_df2[merged_df2['Company']=='Unknown']))
# Out:
# 0
# 0

# %% [markdown]
# ***Data Cleaning Process***

# %% [markdown]
# Dropping duplicates and non English comments

# %%
#Only taking the english comments
english_comments = merged_df2[merged_df2['language'] == 'en']

# Removing the duplicated words
english_comments = english_comments.drop_duplicates(subset=['Comment_Content'])

# %%
len(english_comments)
# Out:
# 103227

# %%
english_comments.sort_values(by='Date', ascending=False).head()
# Out:
#                          Unique_id      Post_id        Author
# 122990  UgwSFVXRHkWGpMxzFbt4AaABAg  l-5lVw42VIs       Lotus F  \
# 122992  UgyQ0dyzYBjdYwZbr1Z4AaABAg  l-5lVw42VIs  Actual Facts
# 122996  Ugz6kUrZ4HcQfUyXXJF4AaABAg  l-5lVw42VIs    Rod Thorpe
# 122998  Ugxh1xbdgnJjybhTBHp4AaABAg  l-5lVw42VIs      Nomad624
# 123000  Ugx5AjkEQ2gjMkJkH9x4AaABAg  l-5lVw42VIs    Ben Jammin
#
#                         Date
# 122990  2023-08-14T11:53:51Z  \
# 122992  2023-08-13T15:23:11Z
# 122996  2023-08-09T15:33:37Z
# 122998  2023-08-08T15:57:07Z
# 123000  2023-08-08T13:27:37Z
#
#                                           Comment_Content  Reply_id
# 122990  Inspiring the younger generations to inspire t...       NaN  \
# 122992                      They forgot to put on a boot.       NaN
# 122996  £38k!?!? 🤯 Yeah "electric cars are soooo expen...       NaN
# 122998  34k for this thing is insane, given that despi...       NaN
# 123000  all electric cars are boring and depreciate li...       NaN
#
#         Reply_Count Parent_id Company language
# 122990          0.0       NaN  Abarth       en
# 122992          0.0       NaN  Abarth       en
# 122996          0.0       NaN  Abarth       en
# 122998          0.0       NaN  Abarth       en
# 123000          0.0       NaN  Abarth       en

# %% [markdown]
# Moving on from basic data cleaning to NLP pre-processing

# %%
#Top 20 words

# Concatenating all the comments into one big string
all_comments = ' '.join(english_comments['Comment_Content'])

# Tokenizing the text into individual words
words = all_comments.split()

# Using Counter to count occurrences of each word
word_counts = Counter(words)

# Finding the 20 most common words
top_twenty_words = word_counts.most_common(20)

# %%
#Top 20 words to be removed from the training corpus as it does not assist in determining topic (Noise)
top_twenty_words_only = [word for word, count in top_twenty_words]
top_twenty_words_only
# Out:
# ['the',
#  'a',
#  'to',
#  'and',
#  'is',
#  'I',
#  'of',
#  'in',
#  'it',
#  'for',
#  'you',
#  'that',
#  'this',
#  'on',
#  'car',
#  'with',
#  'be',
#  'have',
#  'are',
#  'like']

# %%
#Removing frequent rommanised comments that are mistaken for english and unrelated religious comments
def is_noisy(text):
    """Check if a comment is noisy based on the presence of Hindi, Latin and religious keywords."""
    
    hindi_keywords = ["hai", "ke", "ek", "aadmi", "ne", "thayaar", "kar", "unhe", "chahe", "ho", "gaadi", "sarkar", "bania"]
    religious_keywords = ["enki", "archangel", "michael", "demon", "angel", "velit", "sin", "hell", "inferno", "judgment", "pain", "woe", "curse", "jesus", "christ"]
    latin_spanish_keywords = ["coche", "ojos", "cerrado", "pedales", "estan", "facil", "espero", "venta", "fortuna", "americano", "nueva", "cripto", "moneda", "jet", "privado", "futuristca", "espiritu", "santo", "sacerdote", "informatica", "promotora", "sociedad", "auspiciadores", "deleites", "hermosuras", "contenplar", "mandato", "gracia"]

    # Using a simple approach: Count how many keywords are present in the text.
    keyword_count = sum(1 for word in hindi_keywords + religious_keywords + latin_spanish_keywords if word in text.lower())
    
    # If more than a certain threshold of keywords are present, the text is considered noisy.
    return keyword_count >= 4

# %%
#Temporarily putting a is_noisy column to remove noisy comments from function is_noisy
english_comments['is_noisy'] = english_comments['Comment_Content'].apply(is_noisy)

# Drop the rows with noisy comments
english_comments = english_comments[english_comments['is_noisy'] == False]

# Drop the 'is_noisy' column as it's no longer needed
english_comments.drop(columns=['is_noisy'], inplace=True)

# %%
len(english_comments)
# Out:
# 101528

# %%
# Load Spacy model
nlp = spacy.load('en_core_web_sm')

# %%
#Creating a function to be used in NLP pre-processing

def clean_text(text):
    # Parse the text with SpaCy. This runs the entire pipeline.
    doc = nlp(text)
    
    # 'd' contains the difference between set of all characters and the set of punctuations
    d = set(string.printable) - set(string.punctuation)

    # create a new list to hold the modified tokens
    new_tokens = []

    i = 0
    while i < len(doc):
        # If the current token is 'not' and the next token exists
        if doc[i].lemma_ == 'not' and i < len(doc) - 1:
            # append the next token text preceded by 'not_'
            new_tokens.append('not_' + doc[i+1].text)
            # increment i by 2 to skip the next token
            i += 2
        else:
            # otherwise, append the current token lemma
            new_tokens.append(doc[i].lemma_)
            # increment i by 1 to move to the next token
            i += 1

    # Filter tokens that are stop words or punctuation symbols and that are not in the printable set of characters
    tokens = [token for token in new_tokens if not nlp.vocab[token].is_stop and not nlp.vocab[token].is_punct and all([ch in d for ch in token])]
    
    # Lowercase, lemmatize, and remove non-alphabetic characters
    cleaned_tokens = [token.lower() for token in tokens if token.isalpha()]

    # Additional stop words list
    additional_stopwords = ['like', 'go', 'vehicle', 'to', 'abarth', 'andy', 'need', 'want', 'think', 'yeah', 'way', 'lol', 'fiat',
                            'vw', 'volkswagen', 'peugeot','mini', 'tesla', 'honda', 'bmw', 'chrysler', 'toyota', 'people', 'know', 'come', 
                            'maybe', 'thing', 'time', 'start', 'right', 'little', 'vs'] + top_twenty_words_only

    cleaned_tokens = [token for token in cleaned_tokens if token not in additional_stopwords]
    
    
    # Join cleaned tokens back into a string
    cleaned_text = ' '.join(cleaned_tokens)
    
    return cleaned_text

# %%
# Apply preprocessing to each comment
english_comments['Comment_Content'] = english_comments['Comment_Content'].apply(clean_text)

# %%
#Checking how many companies are there
unique_companies = english_comments['Company'].unique()
for company in unique_companies:
    print(company)
# Out:
# Abarth
# Fiat
# Tesla
# Mini
# Volkswagen
# Peugeot

# %% [markdown]
# Making individual dataframes for each companies

# %%
#Separating the dataframe by companies
Abarth = english_comments[english_comments['Company']=='Abarth']
Fiat= english_comments[english_comments['Company']=='Fiat']
Tesla= english_comments[english_comments['Company']=='Tesla']
Mini= english_comments[english_comments['Company']=='Mini']
Volkswagen= english_comments[english_comments['Company']=='Volkswagen']
Peugeot= english_comments[english_comments['Company']=='Peugeot']

# %%
#Making all these comments to list
Abarth_comments = Abarth['Comment_Content'].tolist()
Fiat_comments = Fiat['Comment_Content'].tolist()
Tesla_comments = Tesla['Comment_Content'].tolist()
Mini_comments = Mini['Comment_Content'].tolist()
Volkswagen_comments = Volkswagen['Comment_Content'].tolist()
Peugeot_comments = Peugeot['Comment_Content'].tolist()

# %% [markdown]
# Constructing the ngrams

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

# Tokenise the comments
Abarth_comments = list(sent_to_words(Abarth['Comment_Content']))
Fiat_comments = list(sent_to_words(Fiat['Comment_Content']))
Tesla_comments = list(sent_to_words(Tesla['Comment_Content']))
Mini_comments = list(sent_to_words(Mini['Comment_Content']))
Volkswagen_comments = list(sent_to_words(Volkswagen['Comment_Content']))
Peugeot_comments = list(sent_to_words(Peugeot['Comment_Content']))

# %%
# Train the bigram models
bigram = Phrases(Abarth_comments + Fiat_comments + Tesla_comments + Mini_comments + Volkswagen_comments + Peugeot_comments, min_count=5, threshold=10) # higher threshold fewer phrases.

# %%
# Get a sentence clubbed as a bigram
bigram_mod = Phraser(bigram)

# %%
def make_bigrams(texts, bigram_mod):
    return [bigram_mod[doc] for doc in texts]

# %%
# Form Bigrams
Abarth_comments_bigrams = make_bigrams(Abarth_comments, bigram_mod)
Fiat_comments_bigrams = make_bigrams(Fiat_comments, bigram_mod)
Tesla_comments_bigrams = make_bigrams(Tesla_comments, bigram_mod)
Mini_comments_bigrams = make_bigrams(Mini_comments, bigram_mod)
Volkswagen_comments_bigrams = make_bigrams(Volkswagen_comments, bigram_mod)
Peugeot_comments_bigrams = make_bigrams(Peugeot_comments, bigram_mod)

# %% [markdown]
# Making dictionary to map integer ids and the words

# %%
def create_dict_corpus(texts):
    # Create Dictionary
    id2word = corpora.Dictionary(texts)
    
    # Term Document Frequency
    corpus = [id2word.doc2bow(text) for text in texts]
    
    return id2word, corpus

# %%
#This utilises the bigrams
Abarth_id2word, Abarth_corpus = create_dict_corpus(Abarth_comments_bigrams)
Fiat_id2word, Fiat_corpus = create_dict_corpus(Fiat_comments_bigrams)
Tesla_id2word, Tesla_corpus = create_dict_corpus(Tesla_comments_bigrams)
Mini_id2word, Mini_corpus = create_dict_corpus(Mini_comments_bigrams)
Volkswagen_id2word, Volkswagen_corpus = create_dict_corpus(Volkswagen_comments_bigrams)
Peugeot_id2word, Peugeot_corpus = create_dict_corpus(Peugeot_comments_bigrams)

# %% [markdown]
# Creating the LDA model for each of the company

# %%
def create_lda_models_with_coherence(id2word, corpus, texts, min_topics=3, max_topics=8):
    max_coherence = 0
    best_lda_model = None
    coherence_values = []

    for num_topics in range(min_topics, max_topics):
        print('Round:', num_topics)
        
        lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                                    id2word=id2word,
                                                    num_topics=num_topics,
                                                    random_state=100,
                                                    update_every=1,
                                                    chunksize=100,
                                                    passes=10,
                                                    alpha='auto',
                                                    per_word_topics=True)
        
        cm = CoherenceModel(model=lda_model, texts=texts, dictionary=id2word, coherence='c_v')
        coherence_values.append((num_topics, cm.get_coherence()))
        coherence = cm.get_coherence()

        if coherence > max_coherence:
            max_coherence = coherence
            best_lda_model = lda_model

    return best_lda_model, coherence_values, max_coherence

# %%
Fiat_lda_model, Fiat_C, Fiat_max = create_lda_models_with_coherence(Fiat_id2word, Fiat_corpus, Fiat_comments_bigrams)
Mini_lda_model, Mini_C, Mini_max = create_lda_models_with_coherence(Mini_id2word, Mini_corpus, Mini_comments_bigrams)
Tesla_lda_model, Tesla_C, Tesla_max = create_lda_models_with_coherence(Tesla_id2word, Tesla_corpus, Tesla_comments_bigrams)
Volkswagen_lda_model, Volk_C, Volk_max = create_lda_models_with_coherence(Volkswagen_id2word, Volkswagen_corpus, Volkswagen_comments_bigrams)
Peugeot_lda_model, Peugeot_C, Peugeot_max = create_lda_models_with_coherence(Peugeot_id2word, Peugeot_corpus, Peugeot_comments_bigrams)
# Out:
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7
# Round: 3
# Round: 4
# Round: 5
# Round: 6
# Round: 7

# %%
Abarth_lda_model, Abarth_C, Abarth_max = create_lda_models_with_coherence(Abarth_id2word, Abarth_corpus, Abarth_comments_bigrams, max_topics=5)
# Out:
# Round: 3
# Round: 4

# %%
Abarth_topics = Abarth_lda_model.print_topics(num_words=6)
for topic in Abarth_topics:
    print(topic)
# Out:
# (0, '0.048*"sound" + 0.039*"ev" + 0.030*"engine" + 0.024*"noise" + 0.020*"fun" + 0.012*"ice"')
# (1, '0.027*"look" + 0.025*"love" + 0.019*"great" + 0.017*"good" + 0.015*"price" + 0.013*"range"')
# (2, '0.032*"electric" + 0.020*"drive" + 0.011*"year" + 0.011*"buy" + 0.011*"review" + 0.011*"expensive"')

# %%
Fiat_topics = Fiat_lda_model.print_topics(num_words=6)
for topic in Fiat_topics:
    print(topic)
# Out:
# (0, '0.031*"buy" + 0.030*"drive" + 0.017*"year" + 0.010*"watch" + 0.009*"cost" + 0.008*"fun"')
# (1, '0.027*"look" + 0.026*"good" + 0.025*"ev" + 0.021*"electric" + 0.020*"review" + 0.020*"love"')
# (2, '0.028*"range" + 0.019*"thank" + 0.018*"battery" + 0.017*"charge" + 0.017*"use" + 0.016*"mile"')

# %%
Tesla_topics = Tesla_lda_model.print_topics(num_words=6)
for topic in Tesla_topics:
    print(topic)
# Out:
# (0, '0.127*"hydrogen" + 0.040*"electric" + 0.023*"power" + 0.014*"cost" + 0.011*"tank" + 0.010*"big"')
# (1, '0.043*"engine" + 0.029*"use" + 0.025*"battery" + 0.021*"fuel" + 0.021*"future" + 0.017*"water"')
# (2, '0.050*"ev" + 0.019*"buy" + 0.015*"good" + 0.012*"technology" + 0.010*"year" + 0.010*"look"')

# %%
Mini_topics = Mini_lda_model.print_topics(num_words=7)
for topic in Mini_topics:
    print(topic)
# Out:
# (0, '0.031*"electric" + 0.017*"cool" + 0.014*"use" + 0.012*"drive" + 0.011*"long" + 0.009*"work" + 0.008*"wheel"')
# (1, '0.044*"look" + 0.021*"price" + 0.021*"ev" + 0.020*"battery" + 0.014*"love" + 0.013*"good" + 0.012*"range"')
# (2, '0.046*"design" + 0.032*"motor" + 0.025*"buy" + 0.018*"big" + 0.015*"expensive" + 0.012*"bad" + 0.011*"hope"')

# %%
Volk_topics = Volkswagen_lda_model.print_topics(num_words=9)
for topic in Volk_topics:
    print(topic)
# Out:
# (0, '0.016*"design" + 0.015*"van" + 0.011*"screen" + 0.009*"sell" + 0.009*"day" + 0.008*"yes" + 0.008*"seat" + 0.008*"manufacturer" + 0.008*"market"')
# (1, '0.027*"ev" + 0.026*"look" + 0.022*"range" + 0.017*"battery" + 0.015*"good" + 0.014*"buy" + 0.012*"year" + 0.012*"love" + 0.011*"new"')
# (2, '0.040*"electric" + 0.026*"drive" + 0.018*"use" + 0.013*"small" + 0.010*"software" + 0.008*"family" + 0.008*"bad" + 0.008*"sound" + 0.008*"big"')

# %%
Peugeot_topics = Peugeot_lda_model.print_topics(num_words=8)
for topic in Peugeot_topics:
    print(topic)
# Out:
# (0, '0.028*"french" + 0.020*"version" + 0.016*"wait" + 0.014*"drive" + 0.012*"big" + 0.011*"awesome" + 0.009*"long" + 0.009*"beautiful"')
# (1, '0.023*"model" + 0.020*"year" + 0.018*"engine" + 0.018*"price" + 0.016*"steering_wheel" + 0.016*"headlight" + 0.015*"ev" + 0.011*"inside"')
# (2, '0.030*"buy" + 0.024*"carwow" + 0.017*"electric" + 0.016*"suv" + 0.015*"use" + 0.012*"drive" + 0.011*"bad" + 0.010*"range"')
# (3, '0.049*"look" + 0.045*"review" + 0.039*"new" + 0.035*"good" + 0.022*"love" + 0.022*"design" + 0.022*"matt" + 0.019*"video"')

# %% [markdown]
# Visualising the coherence scores

# %%
def plot_coherence(coherence_values):
    topics, coherences = zip(*coherence_values)
    plt.plot(topics, coherences)
    plt.xlabel("Number of Topics")
    plt.ylabel("Coherence Score")
    plt.show()

# %%
plot_coherence(Abarth_C)

# %%
plot_coherence(Fiat_C)

# %%
plot_coherence(Tesla_C)

# %%
plot_coherence(Mini_C)

# %%
plot_coherence(Volk_C)

# %%
plot_coherence(Peugeot_C)

# %% [markdown]
# Pyldavis Visualisation and top comments for each topics

# %%
# Get the document-to-topic probabilities
def get_document_to_topic(model, corpus):
    doc_to_topic = []
    for doc in corpus:
        topics = model.get_document_topics(doc, minimum_probability=0)
        doc_topics = [prob for _, prob in topics]
        doc_to_topic.append(doc_topics)
    return pd.DataFrame(doc_to_topic)

# Get the top 5 comments for each topic
def print_top_comments_for_topics(model, doc_to_topic, original_comments):
    num_topics = len(model.show_topics())
    for topic_num in range(num_topics):
        top_comments_idx = doc_to_topic.nlargest(5, topic_num).index
        print(f"Topic {topic_num}:")
        print(model.show_topic(topic_num))
        print("Top 5 Comments:")
        for idx in top_comments_idx:
            print(" ".join(original_comments[idx]))
        print("="*40)

# %%
Abarth_doc_to_topic = get_document_to_topic(Abarth_lda_model, Abarth_corpus)
print_top_comments_for_topics(Abarth_lda_model, Abarth_doc_to_topic, Abarth_comments)

#Topic 0: EV Sound and Experience
#Topic 1: Design and Practicality
#Topic 2: Cost and Sustainability
# Out:
# Topic 0:
# [('sound', 0.047584035), ('ev', 0.03915324), ('engine', 0.029535297), ('noise', 0.02370068), ('fun', 0.019670676), ('ice', 0.0117862765), ('nice', 0.01158232), ('turn', 0.011242759), ('stupid', 0.007985429), ('idea', 0.0078058676)]
# Top 5 Comments:
# byd seagull expensive globally geely geometry esuv aka kung fu cow example great fun funky ultra price disruptive chinese ev western anti free market protectionist force determined prevent export worldwide permit cheap ev export floodgate burst open great cheap fun chinese ev seagull geely geometry kung fu cow scandalously cost china finally wake wickedly angry noise zzz generations task doubt paul
# sound low speed protect road user din child false infantile pity mentality customer turn aim
# agree engine noise gear change simulation alternate engine noise cool add handbrake fake clutch fake gear lever software map
# fake engine noise dunno fan hate guitar chord old immediately idea noise theory fake ice noise definitely music thank effort
# yes noise sound simulator selectable sound yr old nissan leaf burble round multi storey carpark sound birdcage maserati steve mcqueen mustang
# ========================================
# Topic 1:
# [('look', 0.02694872), ('love', 0.02501264), ('great', 0.01900511), ('good', 0.016513944), ('price', 0.014662261), ('range', 0.012622544), ('use', 0.011789074), ('small', 0.011544273), ('video', 0.010226083), ('battery', 0.009497746)]
# Top 5 Comments:
# non andrai farfallone amoroso le nozze di figaro mozart anybody wonder song beginning toronto highlight don giovanni palermo beautiful building mozart rear seat fashionable small puffy dog yip entertain try marek good hustle madonna mia coffee cup holder non buono boy cute canada anymore thank entertaining review marek
# agree homepage uk swedish version atrocious barely base price trim level info actually picture version wanna click link picture bring main page reason configurator wanna spec liking cost colour etc pop form fill book test drive contact dealership sale pitch switch german website use configurator seat read use vegan friendly leatherette guess lot evs day try vegan friendly route suppose sense try appeal potential buyer gather homepage sherpa mode limp home eco range suppose eco mode sherpa kinda crap juice home mode limit chance barely door charge point trouble ordinary drive mode emergency resort
# good review wife real blast convertible version month ago gorgeously sunny day boot small rear cramp charm impressed fit finish overall tech range useable battery kwh reminder battery storage kwh battery charging speed kw charge speed mm
# great main issue price huge range far range concern unusable rear seat driver battery pack instead mean use seat tiny percentage wager socket connect main battery slide extension battery pack
# compliment product integration naturally video voiceover product endorsement look product endorse natural audience normally skip video watch actually watchable absolutely high praise
# ========================================
# Topic 2:
# [('electric', 0.032097254), ('drive', 0.019732807), ('year', 0.011247346), ('buy', 0.011071142), ('review', 0.010853555), ('expensive', 0.010833887), ('new', 0.009899975), ('petrol', 0.008428495), ('speaker', 0.007960698), ('bad', 0.007876612)]
# Top 5 Comments:
# version diesel pertrol competizione twinar electric version dissapointment expensive real world drive town suburban area manage km climate winter summer electric drive order meet wltp figure drive consistently slow freeze winter summer city commuter thank mention erratic electronic glitch infotainment aeb etc appear dissapear reason recently begin use petrol twinair automatic rediscover trully great incredibly practical stress free don save maintenance electric petrol hugely overprice heavily susbsidize tax payer money sustainable waste new ton year build house appliance don fail suddenly year normal use earn money greener future politic
# world accept inferior heavy resource hungry hopeless range real world vastly expensive new fuel tank year earth progress minute deny climate change apparent huge shift weather cycle nonsense question problem tick datum box paper prove superiority bit performance figure cry wolf rubbish
# stuff pay aud new fpr comp manual australia pay nearly evee plus sorry government worried environmemt run exist internal combustion engine run water reason government money big con eve save planet
# ruin appreciate work new regulation electric resort hybrid appealing target audience buy brand tuning wackiness basically electric
# imagine pay grand italy electric drive stilo ve hp ton weight second speed mph grand whitput optional gap year old hp normal everyday obnoxious
# ========================================

# %%
Fiat_doc_to_topic = get_document_to_topic(Fiat_lda_model, Fiat_corpus)
print_top_comments_for_topics(Fiat_lda_model, Fiat_doc_to_topic, Fiat_comments)

#Topic 0: Ownership Experience and Practicality
#Topic 1: Aesthetics 
#Topic 2: Range, Battery, and Efficiency
# Out:
# Topic 0:
# [('buy', 0.030819094), ('drive', 0.030311229), ('year', 0.017254654), ('watch', 0.009783393), ('cost', 0.009211367), ('fun', 0.0077005797), ('km', 0.0074932273), ('old', 0.0074611977), ('day', 0.0073017864), ('family', 0.007186418)]
# Top 5 Comments:
# stop russian ukraine russia brother russian propagandist russians try destroy ukrainians ukraine weapon close sky russian rocket kill civilian child thank help ukraine
# year today stopping radar stupid fools cell year company stop sell eat hat hydrogen dirty water green hydrogen clean hydrogen dirty company fail year new company fail far company alive past year
# better brand new stuck service month technician unable discover solve problem th eprobelm faser switch ok problem arise day try try stop believe stop tunnel motorway best experience
# ok let honest buy young couple ok kid seat bring use kid rear seat kid grow staggering use university sport truth uncle year daily man huge forgot tender family huge suv fact mile year mileage suv buy good friend buy forget rule
# mot tester uk suffer rear axle corrode coil spring seat case spring fall rear shock absorber bush wear suspension arm bush wear arm end sit sub frame cause knock
# ========================================
# Topic 1:
# [('look', 0.027027052), ('good', 0.025954198), ('ev', 0.02533778), ('electric', 0.02092907), ('review', 0.020210456), ('love', 0.020066336), ('video', 0.017717747), ('great', 0.017407436), ('price', 0.013063678), ('small', 0.011331107)]
# Top 5 Comments:
# awesome review abi love history add review detail good design love review lately present detail video production ace
# previous comment excellent channel professionally execute great depth review true knowledgeable professional enjoyable watch jonny moment admire style seriously consider interested new ev information informed decision
# winner imo convertible good cup tea look good feels compromise new electric platform interior age
# series jonny feel insight ev ownership advantage renault zoe week august look forward great review sir
# trade twingo gt small ev early perfect similar performance identical dimension interest gadget setting smartphone settle basic version large battery
# ========================================
# Topic 2:
# [('range', 0.028267896), ('thank', 0.018702757), ('battery', 0.018224038), ('charge', 0.01712005), ('use', 0.016919984), ('mile', 0.015751064), ('work', 0.013885316), ('seat', 0.012311455), ('model', 0.010071937), ('city', 0.009079279)]
# Top 5 Comments:
# fun video thank talk energy equivalent far run gallon gas mile gallon equivalent absolute bs kwh battery mile mean gallon gas distance kwh gallon gas kwh total burn ice use kwh gallon rest waste heat exhaust friction equivalency complete bs matter look ice mile gallon gallon mile use kwh gallon kwh use mile energy distance similar surprise mean similar far energy require change physics universe
# british eventually switch international kg sec measure sytem instead medieval foot inch gallon mile stone horseopwer continental abolisherd horsepower use kw calorie use kilojoule kj forbid advertise screen diameter inch horsepower use cm use wrong instead distance kw use km consumption instead distance easy find compare real cost km
# foot inch tall shot clearly inch headroom guess adjust seat height statement later find yes heavy battery battery weight distribute handling ride abrath turbo quick mph real downside range mile stop city driving gather max mph freeway range drop mile drive freeway mph range advertise mile flat level optimal driving condition home ability volt electrical outlet electric clothe dryer use volt volt plug instal garage charge zero charge hour basically daily commute mile round trip able charge home great choice charge work home mile round trip certainly possible
# pull regen regen limit factor ev state charge affect regen rate small kwh battery ton regen heavy able pull easy particular limit regen battery cold battery active heating cooling regen power limit battery temperature
# mile charge guessometer state charge mean chevy spark mile hwy test mile mile shut low battery warning calculate usable kwh suffer degradation mile
# ========================================

# %%
Mini_doc_to_topic = get_document_to_topic(Mini_lda_model, Mini_corpus)
print_top_comments_for_topics(Mini_lda_model, Mini_doc_to_topic, Mini_comments)

#Topic 0: EV Utility and Technical Aspects
#Topic 1: Pricing, Range, and Market Comparison
#Topic 2: Design, Performance, and Environmental Concerns
# Out:
# Topic 0:
# [('electric', 0.030555429), ('cool', 0.01717535), ('use', 0.013850127), ('drive', 0.012460216), ('long', 0.0106986035), ('work', 0.008595042), ('wheel', 0.008463454), ('money', 0.0072864913), ('build', 0.0070149745), ('charge', 0.00686038)]
# Top 5 Comments:
# electric noise emission fuel cost maintenance cost amazing technology gasoline diesel old pollute technology century hydrogen waste money electric electric truck electric bus electric trash hauler electric snow blower electric lawn mower electric snow mobile electric water craft electric garden tool electric mechanic tool electric motor cycle electric bicycle electric scooter electric farm tractor electric construction equipment electric delivery electric worry sit month gas repair
# na chinese guy pout garinty testing figure fast running mean super heat mean sloppy frome hard expert machine coldheader run screw titanium screw pop cut place header wire transfer grab cut red hot cold die load fire cracker bangs pop transfer drop blank hot machine lock slide pooshe pretty run titanium screw run screw directly land rover sit truth eneway alotta fuckin secret number thousand wire size yoused decide remember tight run smooth nice garinty short live try crazy loose instead pre heat gas shur rub slide poshe extra sloppy bet run day radiator cool system
# excuse electric fwd yes awd default rwd electric reason use fwd interior space engine complex fit fwd ev ev lot torque ev torque stand nearly ice super territory yes plenty especially diesel torque issue modern tyre grip handle lot torque rwd handle torque hard acceleration weight shift rear wheel grip wheel fwd opposite hard acceleration lift grip result mean shred tyre bit tiny relative slow tyre initial torque deal breaker
# wash single component aluminum dust thread hole recess area tight corner ect grey grit flush cup flush open eye create grate bit ring instal dry tight fit generous assembly matter instruction drop oil crc qd electrical cleaner compress air dry clean crc rubber component soften certain open cell foam use magnify glass sure clean cool popper thank
# valve system rpm small engine use cam use electronic controller pneumatic valve actuator wonder return pit pressurised air compressor valve use bottle pressure regulator system leak pressurise air usually nitrogen air hard control pressure mixed gas single gas preferable sure small compressor light gas bottle mean add weight zeolite separate significant nitrogen gas air exact
# ========================================
# Topic 1:
# [('look', 0.04441125), ('price', 0.02105507), ('ev', 0.020755945), ('battery', 0.020196095), ('love', 0.013697365), ('good', 0.012997414), ('range', 0.012360354), ('sell', 0.011585621), ('great', 0.011244839), ('new', 0.010186618)]
# Top 5 Comments:
# poland price compare uk carwow mat watson starts pln goverment grant poland normal pln big family card price pln kwh battery motor rwd hp mph km limited speed mph km mph km advanced model cost pln gg gg pln mph km average energy usage km alloys advanced model energy usage km range normally km big alloys range km love design city bc drive km polish motorway range km bc use kwh power dreams electric se starts pln gg pln kwh battery hp mph km limited speed mph km energy usage km range claimed different wltp combined km wltp city claimed km expensive expensive expensive version interior goverment grant price pln pln love speed fly traffic lights new future starts form pln gg pln hp kwh battery good range km mph km speed limited mph km average energy usage km downgrade premium class economy das auto starts huge price pln gg pln option cost crazy pln normal pln gg kwh hp range suppose km mph km limited speed mph km average energy usage km ah opel corsa mean electric mean generation uk vauxhall rest opel price normally starts pln gg pln kwh hp mph km mph km limited speed range km average energy usage km range starts normal pln gg pln wir leben auto finally renault zoe starts pln gg pln version battery kwh hp range km starts pln range starts pln normally gg price pln hp battery kwh good range km incredible mph km speed limited mph km power overtake city average energy usage honeest guys renault bc best range carwow best channel yt greeting poland guys good luck
# suggest use comma stop video presentation follow nice easy talk talk talk talk talk talk talk talk talk andq talk talk talk talk talk talk talk talk talk viewer care uncomfortable listen kind matter good content watch information thousand video maker unpleasant behaviour thank god youtube provide feature channel youtube viewer miserable life video channel watch bunch potential viewer liker subscriber thank attention care
# live city day day lovely corsa good shout ev credential decent city badly refresh age fair play fun drive powerful outperform range spec look ev heavy cooper ice clever lovely inside marmite dial ev range disappoint quote finally zoe good sense mature platform look smart interior vastly improve cheap finance mile long look easily smart choice range primary concern
# love channel mat fair fun love war electric winner cost home charging tank petrol buy far petrol diesel class financial run compare millage achieve cost test fun entertaining unfortunately enfranchise misconception range anxiety focus weak point ev fossil strong point longevity pay dearly ability despite stop food pee journey fair turn table similar test fossil class fair fun good content short trip assume far petrol diesel quid ha ha drive fossil die
# retro nod golf aye renault ev retro look win retro beetle sell hot cake range size price shout elon work year manage new design boss mate comfy seat boring ball
# ========================================
# Topic 2:
# [('design', 0.04553913), ('motor', 0.032029707), ('buy', 0.02459371), ('big', 0.018094448), ('expensive', 0.014908851), ('bad', 0.012087125), ('hope', 0.010890018), ('quality', 0.009213099), ('matt', 0.008133079), ('hp', 0.006930332)]
# Top 5 Comments:
# alternate text lot english actually mean speak situation old lady look fucking care matt roll roll imna let drive bit charge old lady cheeky fuck cough cough matt wink wink old lady charge point fuck cough cough fuck let use electric pay tv license matt pin plug old lady fella live point garage fucking bother tosser london leave old old lady sure problem
# accord report friend earth lithium extraction inevitably harm soil cause air contamination argentina salar de hombre muerto local claim lithium operation contaminate stream use human livestock crop irrigation chile clash mining company local community lithium mining leave landscape mar mountain discard salt canal fill contaminated water unnatural blue hue mining process invasive scar landscape destroy water table pollute earth local guillermo gonzalez lithium battery expert university chile interview green solution solution
# strength regen bake high speed directly proportion power motor simply motor work generator capable hp drive hp work reverse generator equal able absorb twice kinetic energy convert electrical energy kinetic energy square speed high speed lot energy absorb mph metre second motor capable absorb kw second worth braking absorb kj energy slow kg absorb kw low speed kinetic energy lot low square relationship mph kw version capable slow second interval use regen principle approach emergency stop rate deliberately limit kw difference disappear low speed considerably complex issue wind rolling resistance play role electronic power angular speed relationship motor basic apply principle ev equal mass accelerate fast regenerative braking capability obvious high speed assume aspect comparable
# bldc motor size capable output lie pure simple talk motor able output kind power doubt video title dishonest click bait liar author video title motor claim able sustain output megawatt second motor driver circuitry sustain damage actual driving condition claim downright liar watch video tell likely lie hot air hope uploader video indirectly claim possible technology available today
# normally ur headgasket ur exhaust blow white smoke check ur oil stick goowey white water throw ur oil cap sludgy day new ar boy racer chin bro
# ========================================

# %%
Tesla_doc_to_topic = get_document_to_topic(Tesla_lda_model, Tesla_corpus)
print_top_comments_for_topics(Tesla_lda_model, Tesla_doc_to_topic, Tesla_comments)

#Topic 0: Hydrogen vs Electric
#Topic 1: Engines, Batteries, and Environmental Impact
#Topic 2: EV market and competitors
# Out:
# Topic 0:
# [('hydrogen', 0.12709059), ('electric', 0.039552823), ('power', 0.022634909), ('cost', 0.013532576), ('tank', 0.010907592), ('big', 0.009741916), ('oil', 0.009268309), ('motor', 0.008286831), ('electricity', 0.007966182), ('efficient', 0.0068283165)]
# Top 5 Comments:
# tank turn dumb idea tread turn spin slide friction wich familiar winter slide uncontrollably tank turn summer grippy road shit ton energy ruin tire kick debris dangerous high wheelspeed compare happy winter sliding incline bet end downhill regardle turning intention compensate issue tread wheel dumb idea spin stationary tire use ancor control turn ruin tank turn idea bit feel rotary axis pretty center simulate controllable fashion swich anchor wheel avrg turn middle spin tire pretty instantly imagine multiple burnout tire turn cooler break tire wirk anchor spin bit anymore roll turn prop read far hope enjoy quick excourse dumb idea tankturn wheel
# high low usually refer voltage dc power circuit imagine sticky stuff heat sink compound conduct heat away brilliant piece design power electronic nice close motor heat away coolant set semiconductor switch arrange end motor winding connect high low circuit board arrange triangle obviously end winding connect high low blam bridge use motor control control current winding rapidly switch bridge loss minimise rapid switching current flow freewheel diode allow current continue flow switch prevent massive emf voltage destroy switch
# okay fellow let motor big understand electronic probably big mosfet driver drive micro controller big wire motor typical brushless dc motor phase white wire motor stator position information computer step change magnetic field motor throw electronic install clear coat stuff wonder use protect electronic chip moisture plastic package crack plastic small water particle vapor form vapor condensation turn droplet inside chip land chip connection disrupt jell protect chip unwanted vapor
# sigh wire phase inverter connect control motor brain inverter brawn motor reducer phase induction motor reducer oil cool silicon igbt switch inverter coolant cool nail cuz high copper density motor good design course high inverter coolant fluid require inverter operate operating temperature cool oil stack plate heat exchanger motor reducer operating temperature
# disassemble motor assembly actual motor orange high voltage wire connect inverter create phase ac ac motor control circuit schematic educate guess battery power buck boost converter constant voltage triple half bridge control electronic fast efficient possible cent second gear bearing speed gearbox combine differential motor
# ========================================
# Topic 1:
# [('engine', 0.04254496), ('use', 0.02881958), ('battery', 0.024965577), ('fuel', 0.020819452), ('future', 0.020730125), ('water', 0.016620075), ('video', 0.01437296), ('charge', 0.0130296955), ('gas', 0.013006563), ('energy', 0.012300352)]
# Top 5 Comments:
# half lifetime carbon dioxide emission electric energy use produce especially mining processing raw material battery compare unfavorably manufacture gasoline power account lifetime carbon dioxide emission new ev appear room cause pound carbon dioxide emission equivalent manufacture conventional pound road carbon dioxide emission evs depend power generation fuel use recharge battery coal fire power plant lead ounce carbon dioxide mile drive ounce similar gasoline power reference source electricity use battery charging ev drive mile lifetime huge initial emission manufacture mean ev actually carbon dioxide atmosphere similar size gasoline power drive number mile battery replace lifetime future wrong ev
# yep rubbish live australia use yep huge cable lock nacs plug year large road trip bocha chica ksc use super charger issue course feel nacs nacs female shroud cover assembly protect water ingress wash charge worry extra female cover shroud offer water shedding extra safety definitely nacs plug size nacs look lot small deal breaker nacs extra water shed skirt extra point note ac charge connector similar size nacs hole lever lock charge home ac connector fine best charger connectors ac dc rf button ope close unlock
# problem hydrogen solve easily use water fuel water add multiple alternator powerful increase energy produce engine use energy split water hydrogen oxygen oxygen remove extra air combustion problem create hydrogen oxygen burn demand press gas gas produce system produce waste electrolysis flush filter remove certain byproduct electrolysis production hho cell order hho cell clean small tank beginning pressurize hydrogen oxygen regulate fuel pressure problem safe work corporation sell water fuel gas sale tax cost gallon generate carbon tax moment opec determine value currency gold standard mean world new control currency exchange value
# swappable battery exchange minute recharge hour solution long recharge currently experience charge station battery electric city china taxi use year ago xiamen taxi drive fully automate battery swapping station robotically battery pack replace fully charge pack depleted pack carry away charge ready use later operation minute
# iranian engineer farhad imani design engine charge fuel charge travel kilometer example engine charge practically emit gravity lead movement movement enter second phase production lead production high power torque speed km thousand mile charge distance world travel kilometer fuel recharge introduce world iran step construction iran cost maximum later important introduce world app
# ========================================
# Topic 2:
# [('ev', 0.050012384), ('buy', 0.018622499), ('good', 0.01512711), ('technology', 0.0121481065), ('year', 0.010340908), ('look', 0.009641286), ('great', 0.008822902), ('company', 0.008213394), ('evs', 0.007949931), ('expensive', 0.0073207356)]
# Top 5 Comments:
# manufacturing crash look ahead charge network generate profit foreseeable future ford ev owner use charging company predict enhance earning ahead bet ford hope create charging network find difficult expensive company grab income product sell ford hate idea customer send money compete company deal
# surprising usa standardized plug ev example standardized plug ev europe big portion supercharger open non bev usa big portion supercharger open non bev europe usa different socket stop follow electrification progression usa stagnation look somewhat curious video pique interest pond ps mercedes benz volkwagen audi porsche volvo hyundai polestar lynk co byd nio xpeng cupra etc sell bev usa market surprising hear ford second sell bev brand usa canada bad
# believe cooperation ford benefit ford economically corner ev market elon musk attempt help fellow ev auto industry ford believe jim farley elon musk business friend stock ford look forward ford ev market
# politic death ask dumb question reason fully support ford ev customer electrify america complete garbage period entire month issue ultimately lead buy home charger soon plan error slow speed getting charge fast charging rate till
# question china sell india govt job investment china money india great decision govt apparently apple try create situation apple store govern indian rule enter apple store apple american company imperial law kind mindset
# ========================================

# %%
Volk_doc_to_topic = get_document_to_topic(Volkswagen_lda_model, Volkswagen_corpus)
print_top_comments_for_topics(Volkswagen_lda_model, Volk_doc_to_topic, Volkswagen_comments)

#Topic 0: Regulations, Market Dynamics, and Global Strategy
#Topic 1: EV Features, Pricing, and Consumer Preferences
#Topic 2: Vehicle Design, Features, and Historical Perspectives
# Out:
# Topic 0:
# [('design', 0.016372489), ('van', 0.014622519), ('screen', 0.010939787), ('sell', 0.008603998), ('day', 0.008587874), ('yes', 0.008402588), ('seat', 0.008045605), ('manufacturer', 0.007904631), ('market', 0.007867214), ('engine', 0.007583914)]
# Top 5 Comments:
# fsd design wrong day fix safety white paper describe fsd weather safety temperature altitude define fsd track sensor mount read temp road surface instal cost temp road surface allow fsd change temp close freezing outside temp temp windshield important bet elon thermometer attach windshield detect freezing condition fsd total disaster buck common sense engineering monumental difference autonomous driving run driver
# economic balance talk billion asians africa billion south america million eastern europe million south eastern europe million southern europe million billion canada million australia new zealand million usa million western europe gas million million island iceland greenland etc billion overall
# model ys usa contrary sam comment formally meet requirement qualify ira tax credit msrp cap apply seater model ys fail attract high suv msrp cap kg adult occupy seat seat model laden weight probably low lbs number suggest figure irs reckoning classify suv advice simple consideration seat model ys suv classification prejudge matter clear irs aim use classification determine consistent rule definition provide cfr van sport utility pickup truck additionally irs announce plan issue regulation define specific term revise rename clean credit regulation set definition follow term final assembly north america manufacturer suggest retail price classifications van sport utility pickup truck place service
# group long history new life old brand bugatti skoda bentley etc leader piech winterkorn company result forward success bugatti crunch market year budget bentley gradual improvement skoda resell old platform new discount brand stretch return investment far case succeed long run situation uniquely different strategy use duplicate critically explain lot success launch brand new product scratch importantly budget exactly scout project currently struggle amortize cost electric profitable bad amarok truck electifation mind mix stale truck platform exist battery tech cost effective good slap truck road look body exist suv day platform expect scout lineup ford bronco jeep wrangler etc bode project goal market asap competitive low price road ev truck detail project sound potentially genius succeed partner automaker ford base current project partnership group position successfully execute goal generation specific product seriously organization dna
# japanese government japan join hip profound ramification execute corporate vision understand framework fud bev demente inability accept bet farm wrong horse regard hydrogen sense clear japanese government ensure china bev import japan large number high duty tariff likely ability plan permission fast charging impossible utility force charge excessive ev charge operator understand understand position ev happy japanese market africa latin america caribbean ice sale low level mean pay carbon tax credit ev producer
# ========================================
# Topic 1:
# [('ev', 0.02691363), ('look', 0.02578525), ('range', 0.02237563), ('battery', 0.017211), ('good', 0.01508637), ('buy', 0.0135591645), ('year', 0.012476716), ('love', 0.012355227), ('new', 0.011368538), ('review', 0.010159545)]
# Top 5 Comments:
# regard software annoying bug solve edition announce unfinished software beta state resolve software update fine regard price expensive version lot expensive gimmick compare ev cheap good package modern ev package high perfomance toy expensive modern ev geometry model model pay instrument cluster display wheel good package fair price sell lot shit sure care touch crap face lift version year sure range cost
print_top_comments_for_topics(Peugeot_lda_model, Peugeot_doc_to_topic, Peugeot_comments)

#0. Design and variants
#1. Features and pricing
#2. Driving Experience, Electric Range, and Purchase Insights
#3. Reviews and Overall Sentiments
# Out:
# Topic 0:
# [('french', 0.028481822), ('version', 0.019836595), ('wait', 0.015999634), ('drive', 0.014250135), ('big', 0.011671511), ('awesome', 0.011186154), ('long', 0.009245628), ('beautiful', 0.008933399), ('gt', 0.008391012), ('cost', 0.008387703)]
# Top 5 Comments:
# suv baffle unimaginative establish automaker xd sayin shrimp fruit sea barbecue boil broil bake saute dey uh shrimp kabob shrimp creole shrimp gumbo pan fry deep fry stir fry pineapple shrimp lemon shrimp coconut shrimp pepper shrimp shrimp soup shrimp stew shrimp salad shrimp potato shrimp burger shrimp sandwich bubba forest gump
# aneise girl beach brain girl woman ali world speak foi american woman life beautiful woman die life speak poder comunication diferent eye speak ir
# year impress concept creation somebody woke guess wow hype introduction ugly look having metal roller high school shop class ps notice word beauty pss wear sneaker
# spend true money spend happy practical object safely comfort quick nice look cost half spend
# gold gt version yesterday true beauty
# ========================================
# Topic 1:
# [('model', 0.023338737), ('year', 0.020261033), ('engine', 0.018122606), ('price', 0.017940484), ('steering_wheel', 0.016443407), ('headlight', 0.015725419), ('ev', 0.015460619), ('inside', 0.011101602), ('seat', 0.009760786), ('bit', 0.009195874)]
# Top 5 Comments:
# hate new badge look big ugly bandage confuse epl proton logo big mistake change good luck talisman insignia stylised standing proud metallic lion bring wrc championship trophies fame fortune decade old insignia order
# peace mercy blessing god islamic preacher ahmed invite servant god king heavens earth believe messenger ourmaster muhammad read book god noble repent return god cultivate world end escape torment god hope read comment act
# hate new badge look big ugly bandage big mistake change good luck talisman stylise standing proud metallic lion insignia bring wrc championship trophies fame fortune decade old stylised metallic insignia order
# decent look manufacturer silly price look site pcp whopping deposit year mile year deal cheap active premium model option basic petrol puretech deal deposit year mile year deal big issue remain manufacturer load chintzy bling ask dollar bet low spec cheape spec wise offer active premium let honest proper job offer basic thousand petrol great deal rational sense thousand moment cheap bling add
# question adjust temp kinda physical button volume temp etc set favourite temp leave volume nice easy access cool song radio tidal temp change temperature year prefer degree morning midday evening separate button use review channel mention problem kind set touch winter summer degree outside modern meet desire temp imho leave correct wrong pls semi rant sorry enjoy evening
# ========================================
# Topic 2:
# [('buy', 0.03031613), ('carwow', 0.024302375), ('electric', 0.016999505), ('suv', 0.016181193), ('use', 0.015469543), ('drive', 0.012266984), ('bad', 0.0110621285), ('range', 0.0100811655), ('mile', 0.009021256), ('watch', 0.0086779)]
# Top 5 Comments:
# loaner diesel service thoroughly enjoy drive drive aimlessly experience smooth linear power delivery course quiet mention intrusive road noise intrusive ride quietly smoothly drive rough road space inside ok find space seat adequate find visibility restrictive rear view mirror sharply rake windscreen half windscreen block lot view left find judge near bit tricky high bonnet line squeeze narrow gap traffic tricky quickly high tech sat nav apple google play reverse camera inductive charging smart phone etc range fully charge eco mode range mile mile normal sport mode find eco mode bit sluggish accelerator require fair push nicely heating air con restrict mode normal sport ice mode use eco mode range leave mile mile use normal sport mode lot heating extra charge use sum impressed look big seriously consider consider discover price spec new allure mile clock retail fraction hefty price pay electric motor lithium battery consider mainly use locally drive tech intrigue electric use lot motorway mile great city drive locally exhaust locally drive simply pollution ie power station pollution deal place filter etc big plus
# idea electric suv find strange single electric wagon estate available europe uk family suv
# reason robert predict range drive highway day range readjust low consumption city driving range estumation rapidly high low consumption intentional range prediction rapidly stress mind use abrp plan trip care range cheers
# problem tyre low rolling resistance mean overall reduced grip mean rely traction control abs corner ability reduce law physics bad look happy performance figure compromise design petrol diesel
# let honest suv scream compromise term battery efficiency range great feat platform sit heat pump play catch inverter sustain dc charge speed market family today ev world lack party charge station sorry vacation visit relative live away regard negative aspect bobby find rear camera absence high level trim indoor led ambiance light actually dimmable comment section puzzle ask uk fail present hand psa kinda fc seriously troll
# ========================================
# Topic 3:
# [('look', 0.049418855), ('review', 0.04548297), ('new', 0.038654007), ('good', 0.035068084), ('love', 0.02225661), ('design', 0.022190109), ('matt', 0.021819482), ('video', 0.018572059), ('mat', 0.01845473), ('great', 0.01653077)]
# Top 5 Comments:
# cool futuristic design cool exterior interior cool futuristic futuristic technology adorable taste past overall darn cool good video blondie
# test new audi new series new mercedes class new jaguar xj new lexus ls new kia new genesis agree battleofthelimo matt
# test new audi new series new mercedes class new jaguar xj new lexus ls new kia new genesis agree battleofthelimo matt
# child early parent bring elementary school design boring love design rear design remind alfa romeo
# hey love review new slate jaguar curious certainly look new xe actually xf pace fan carbuyer day great cheer uganda cheer
# ========================================

# %%
# Visualize Abarth model
Abarth_vis = gensimvis.prepare(Abarth_lda_model, Abarth_corpus, Abarth_id2word)
pyLDAvis.display(Abarth_vis)
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el37933115879842243317482523" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el37933115879842243317482523_data = {"mdsDat": {"x": [-0.04659778846395613, -0.17389479543556058, 0.2204925838995168], "y": [-0.22129861659199707, 0.14986972962656547, 0.07142888696543158], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [34.50503443470124, 33.4243536895566, 32.07061187574217]}, "tinfo": {"Term": ["sound", "ev", "electric", "engine", "look", "love", "noise", "drive", "fun", "great", "good", "price", "range", "use", "ice", "small", "nice", "year", "turn", "buy", "review", "expensive", "video", "new", "battery", "big", "version", "petrol", "stupid", "speaker", "electric", "drive", "buy", "year", "new", "expensive", "review", "petrol", "bad", "feel", "money", "hope", "speaker", "thank", "mile", "real", "future", "sound_generator", "city", "inside", "fake_sound", "gas", "evs", "actually", "far", "silent", "brand", "miss", "end", "heavy", "sorry", "play", "system", "look", "love", "great", "good", "price", "range", "small", "use", "video", "battery", "big", "power", "sell", "charge", "try", "cost", "motor", "hear", "model", "performance", "interesting", "design", "cheap", "lot", "speed", "driver", "guy", "day", "yes", "young", "tiny", "compare", "version", "sound", "engine", "noise", "fun", "ice", "nice", "turn", "fake", "stupid", "idea", "ev", "cool", "long", "find", "old", "italian", "fan", "market", "hate", "add", "fast", "road", "face", "pretty", "sure", "owner", "fact", "stick", "open", "cute", "change", "bath", "chinese", "work"], "
 73.65195384132295, 170.77810923331305, 248.68217484908098, 215.88818776999497, 193.10252630283742, 191.16195457646032, 175.21009218033885, 164.73814783536437, 167.55968347420023, 118.29133879292374, 104.00449074868035, 97.98516774765329, 87.95784844461305, 77.98007746953571, 80.07173537521089, 72.22246847879616, 71.6772632089292, 70.87782133016069, 74.21375455126869, 66.97623038496351, 66.34355390804089, 64.09478622301289, 60.95609365213332, 60.87962270975758, 55.80390112291201, 55.538411198586864, 51.23749625634841, 49.87319053817669, 51.96294312060554, 52.88980845325101, 49.403131415615775, 43.88641184749496, 49.85887580493285, 51.98799018244779, 293.10358744928044, 204.13641133343648, 164.65062968495815, 120.1103514019556, 115.11558316687382, 95.14582601670364, 91.93271223328303, 86.31701591497 ...

# %% [markdown]
# Timeline graphs

# %%
# Convert the 'Date' column to datetime type
Abarth['Date'] = pd.to_datetime(Abarth['Date'])
Fiat['Date'] = pd.to_datetime(Fiat['Date'])
Tesla['Date'] = pd.to_datetime(Tesla['Date'])
Mini['Date'] = pd.to_datetime(Mini['Date'])
Volkswagen['Date'] = pd.to_datetime(Volkswagen['Date'])
Peugeot['Date'] = pd.to_datetime(Peugeot['Date'])


# Extract the year-month
Abarth['Year_Month'] = Abarth['Date'].dt.to_period('M')
Fiat['Year_Month'] = Fiat['Date'].dt.to_period('M')
Tesla['Year_Month'] = Tesla['Date'].dt.to_period('M')
Mini['Year_Month'] = Mini['Date'].dt.to_period('M')
Volkswagen['Year_Month'] = Volkswagen['Date'].dt.to_period('M')
Peugeot['Year_Month'] = Peugeot['Date'].dt.to_period('M')
# Out:
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Abarth['Date'] = pd.to_datetime(Abarth['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fiat['Date'] = pd.to_datetime(Fiat['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tesla['Date'] = pd.to_datetime(Tesla['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mini['Date'] = pd.to_datetime(Mini['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Volkswagen['Date'] = pd.to_datetime(Volkswagen['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Peugeot['Date'] = pd.to_datetime(Peugeot['Date'])
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:11: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Abarth['Year_Month'] = Abarth['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Abarth['Year_Month'] = Abarth['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:12: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Fiat['Year_Month'] = Fiat['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fiat['Year_Month'] = Fiat['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:13: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Tesla['Year_Month'] = Tesla['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tesla['Year_Month'] = Tesla['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:14: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Mini['Year_Month'] = Mini['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mini['Year_Month'] = Mini['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:15: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Volkswagen['Year_Month'] = Volkswagen['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Volkswagen['Year_Month'] = Volkswagen['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:16: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   Peugeot['Year_Month'] = Peugeot['Date'].dt.to_period('M')
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2645143372.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Peugeot['Year_Month'] = Peugeot['Date'].dt.to_period('M')

# %%
def get_relevant_topics(lda_model, comment, threshold=False):
    topics = lda_model.get_document_topics(comment)
    #Returns the ID and the probability
    return [(topic[0], topic[1]) for topic in topics]

Abarth_doc_topics = [get_relevant_topics(Abarth_lda_model, comment) for comment in Abarth_corpus]
Fiat_doc_topics = [get_relevant_topics(Fiat_lda_model, comment) for comment in Fiat_corpus]
Tesla_doc_topics = [get_relevant_topics(Tesla_lda_model, comment) for comment in Tesla_corpus]
Mini_doc_topics = [get_relevant_topics(Mini_lda_model, comment) for comment in Mini_corpus]
Volk_doc_topics = [get_relevant_topics(Volkswagen_lda_model, comment) for comment in Volkswagen_corpus]
Peugeot_doc_topics = [get_relevant_topics(Peugeot_lda_model, comment) for comment in Peugeot_corpus]

# %%
# 1. Modify the DataFrame to have another column on the lists of topics to their respective comments
Abarth['Topics'] = Abarth_doc_topics
Fiat['Topics'] = Fiat_doc_topics
Tesla['Topics'] = Tesla_doc_topics
Mini['Topics'] = Mini_doc_topics
Volkswagen['Topics'] = Volk_doc_topics
Peugeot['Topics'] = Peugeot_doc_topics

# Helper function to count topic occurrences by year-month.
def count_topics_by_year_month(df):
    all_sums = []
    grouped = df.groupby('Year_Month')
    for name, group in grouped:
        for topic_num in set(topic for topics in group['Topics'] for topic, _ in topics):
            topic_prob_sum = sum(prob for topics in group['Topics'] for topic, prob in topics if topic == topic_num)
            all_sums.append((name, topic_num, topic_prob_sum))
    return pd.DataFrame(all_sums, columns=['Year_Month', 'Topic', 'Sum_Probability'])

# 2. Count occurrences of each topic by year-month.
topic_counts_by_year_Abarth = count_topics_by_year_month(Abarth)
topic_counts_by_year_Fiat = count_topics_by_year_month(Fiat)
topic_counts_by_year_Tesla = count_topics_by_year_month(Tesla)
topic_counts_by_year_Mini = count_topics_by_year_month(Mini)
topic_counts_by_year_Volkswagen = count_topics_by_year_month(Volkswagen)
topic_counts_by_year_Peugeot = count_topics_by_year_month(Peugeot)

# 3. Filter datasets to only take the dates with significant trends
topic_counts_by_year_Abarth = topic_counts_by_year_Abarth[topic_counts_by_year_Abarth['Year_Month'] > pd.Period('2019-12')]
topic_counts_by_year_Fiat = topic_counts_by_year_Fiat[topic_counts_by_year_Fiat['Year_Month'] > pd.Period('2016-12')]
# Out:
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Abarth['Topics'] = Abarth_doc_topics
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Fiat['Topics'] = Fiat_doc_topics
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tesla['Topics'] = Tesla_doc_topics
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Mini['Topics'] = Mini_doc_topics
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Volkswagen['Topics'] = Volk_doc_topics
# /var/folders/yt/slyrm7113271w310_rtxsbnw0000gn/T/ipykernel_1707/2762588132.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Peugeot['Topics'] = Peugeot_doc_topics

# %%
topic_names_abarth = {
    0: 'EV Sound and Experience',
    1: 'Design and Practicality',
    2: 'Cost and Sustainability'
}

topic_counts_by_year_Abarth['Topic'] = topic_counts_by_year_Abarth['Topic'].replace(topic_names_abarth)

topic_counts_by_year_Abarth['Year_Month'] = topic_counts_by_year_Abarth['Year_Month'].astype(str)

plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Abarth, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Abarth: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
topic_names_Fiat = {
     0: 'Ownership Experience and Practicality',
     1: 'Aesthetics',
     2: 'Range, Battery, and Efficiency'
}

topic_counts_by_year_Fiat['Topic'] = topic_counts_by_year_Fiat['Topic'].replace(topic_names_Fiat)


# Convert the PeriodIndex to string
topic_counts_by_year_Fiat['Year_Month'] = topic_counts_by_year_Fiat['Year_Month'].astype(str)


plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Fiat, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Fiat: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
topic_names_Tesla = {
    0: 'Hydrogen vs Electric',
    1: 'Engines, Batteries, and Environmental Impact',
    2: 'EV market and competitors'
}

topic_counts_by_year_Tesla['Topic'] = topic_counts_by_year_Tesla['Topic'].replace(topic_names_Tesla)

# Convert the PeriodIndex to string
topic_counts_by_year_Tesla['Year_Month'] = topic_counts_by_year_Tesla['Year_Month'].astype(str)


plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Tesla, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Tesla: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
topic_names_Mini = {
    0: 'EV Utility and Technical Aspects',
    1: 'Pricing, Range, and Market Comparison',
    2: 'Design, Performance, and Environmental Concerns'
}

topic_counts_by_year_Mini['Topic'] = topic_counts_by_year_Mini['Topic'].replace(topic_names_Mini)


# Convert the PeriodIndex to string
topic_counts_by_year_Mini['Year_Month'] = topic_counts_by_year_Mini['Year_Month'].astype(str)


plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Mini, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Mini: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
topic_names_Volk = {
   0: 'Regulations, Market Dynamics, and Global Strategy',
   1: 'EV Features, Pricing, and Consumer Preferences',
   2: 'Vehicle Design, Features, and Historical Perspectives'
}

topic_counts_by_year_Volkswagen['Topic'] = topic_counts_by_year_Volkswagen['Topic'].replace(topic_names_Volk)

# Convert the PeriodIndex to string
topic_counts_by_year_Volkswagen['Year_Month'] = topic_counts_by_year_Volkswagen['Year_Month'].astype(str)


plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Volkswagen, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Volkswagen: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %%
topic_names_Peugeot = {
  0: 'Design and variants',
  1: 'Features and pricing',
  2: 'Driving Experience, Electric Range, and Purchase Insights',
  3: 'Reviews and Overall Sentiments'
}

topic_counts_by_year_Peugeot['Topic'] = topic_counts_by_year_Peugeot['Topic'].replace(topic_names_Peugeot)

# Convert the PeriodIndex to string
topic_counts_by_year_Peugeot['Year_Month'] = topic_counts_by_year_Peugeot['Year_Month'].astype(str)

plt.figure(figsize=(14, 8))
sns.lineplot(data=topic_counts_by_year_Peugeot, x='Year_Month', y='Sum_Probability', hue='Topic')
plt.title('Peugeot: Weighted Frequency of Topics Over Time')
plt.xlabel('Year and Month')
plt.ylabel('Weighted Frequency (Sum of Probabilities)')
plt.legend(title='Topic')
plt.grid(True, linestyle='--')
plt.tight_layout()
plt.xticks(rotation=90)  # Rotate x-axis labels for better readability

plt.show()

# %% [markdown]
# Saving dataset with topics

# %%
# Save df2_combined as CSV
Abarth.to_csv('Abarth.csv', index=False)
Fiat.to_csv('Fiat.csv', index=False)
Tesla.to_csv('Tesla.csv', index=False)
Mini.to_csv('Mini.csv', index=False)
Volkswagen.to_csv('Volkswagen.csv', index=False)
Peugeot.to_csv('Peugeot.csv', index=False)

# %% [markdown]
# Top Common words for Combustion and EV Abarth for basic understanding of its meaning system

# %%
a = english_comments[english_comments['Company'] == 'Abarth']

# %%
#Utilise the date of announcement for Abarth 500e EV car
Abarth_EV = a[a['Date'] >= '2022-11-22T13:00:00Z']
Abarth_Combustion = a[a['Date'] < '2022-11-22T13:00:00Z']

# %%
#Top 20 words

# Concatenating all the comments into one big string
a_ev_comments = ' '.join(Abarth_EV['Comment_Content'])
a_Com_comments = ' '.join(Abarth_Combustion['Comment_Content'])

# Tokenizing the text into individual words
Meaning_abarth_EV = a_ev_comments.split()
Meaning_abarth_Combustion = a_Com_comments.split()

# Using Counter to count occurrences of each word
word_counts0 = Counter(Meaning_abarth_EV)
word_counts1 = Counter(Meaning_abarth_Combustion)

# Finding the 20 most common words
top_twenty_words_AEV = word_counts0.most_common(15)
top_twenty_words_AComb = word_counts1.most_common(15)

# %%
top_twenty_words_AEV
# Out:
# [('sound', 1005),
#  ('ev', 504),
#  ('noise', 469),
#  ('electric', 467),
#  ('look', 426),
#  ('love', 335),
#  ('engine', 320),
#  ('fake', 308),
#  ('range', 262),
#  ('drive', 242),
#  ('great', 227),
#  ('good', 220),
#  ('fun', 195),
#  ('price', 179),
#  ('petrol', 165)]

# %%
top_twenty_words_AComb
# Out:
# [('engine', 55),
#  ('look', 40),
#  ('great', 34),
#  ('drive', 34),
#  ('good', 33),
#  ('electric', 31),
#  ('ev', 30),
#  ('video', 28),
#  ('use', 26),
#  ('range', 24),
#  ('review', 24),
#  ('price', 24),
#  ('small', 23),
#  ('valve', 23),
#  ('guzzi', 23)]
